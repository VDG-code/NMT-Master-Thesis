# %% [markdown]
# <a href="https://colab.research.google.com/github/VDG-code/NMT-Master-Thesis/blob/main/mbart50_large_evaluation_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
evaluation_df = pd.read_csv('/content/drive/MyDrive/evaluation_df.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
# !pip install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.25.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast
import pandas as pd
from sacrebleu.metrics import BLEU

# %%
model_name = "facebook/mbart-large-50-many-to-many-mmt"
tokenizer = MBart50TokenizerFast.from_pretrained(model_name)
model = MBartForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
def translate_dutch_to_croatian_batch(texts):
    # Set the tokenizer's source language code for Dutch. mBART uses 'nl_XX' for Dutch.
    tokenizer.src_lang = "nl_XX"
    # Encode the Dutch texts
    encoded_nl = tokenizer(texts, return_tensors="pt", padding=True, truncation=True, max_length=512).to('cuda')
    generated_tokens = model.generate(**encoded_nl, forced_bos_token_id=tokenizer.lang_code_to_id["hr_HR"])
    # Decode the generated tokens to texts
    return [tokenizer.decode(g, skip_special_tokens=True) for g in generated_tokens]

def translate_croatian_to_dutch_batch(texts):
    # Set the tokenizer's source language code for Croatian. mBART uses 'hr_XX' for Croatian.
    tokenizer.src_lang = "hr_HR"
    # Encode the Croatian texts
    encoded_hr = tokenizer(texts, return_tensors="pt", padding=True, truncation=True, max_length=512).to('cuda')
    generated_tokens = model.generate(**encoded_hr, forced_bos_token_id=tokenizer.lang_code_to_id["nl_XX"])
    # Decode the generated tokens to texts
    return [tokenizer.decode(g, skip_special_tokens=True) for g in generated_tokens]

# %%
model = model.to('cuda')  # Move model to GPU

# %%
from tqdm.auto import tqdm
import torch

bleu = BLEU()

# Prepare lists for translations and scores
croatian_to_dutch_translations = []
dutch_to_croatian_translations = []
croatian_to_dutch_bleu_scores = []
dutch_to_croatian_bleu_scores = []

batch_size = 8  #
for i in tqdm(range(0, len(evaluation_df), batch_size)):
    batch = evaluation_df.iloc[i:i+batch_size]

    # Translate batches
    translated_dutch_batch = translate_croatian_to_dutch_batch(batch['Croatian'].tolist())  # Batch translation function
    translated_croatian_batch = translate_dutch_to_croatian_batch(batch['Dutch'].tolist())  # Batch translation function

    croatian_to_dutch_translations.extend(translated_dutch_batch)
    dutch_to_croatian_translations.extend(translated_croatian_batch)

    # Compute BLEU scores in batch
    for translated_dutch, translated_croatian, original_dutch, original_croatian in zip(translated_dutch_batch, translated_croatian_batch, batch['Dutch'].tolist(), batch['Croatian'].tolist()):
        dutch_score = bleu.corpus_score([translated_dutch], [[original_dutch]])
        croatian_score = bleu.corpus_score([translated_croatian], [[original_croatian]])

        croatian_to_dutch_bleu_scores.append(dutch_score.score)
        dutch_to_croatian_bleu_scores.append(croatian_score.score)

# Update DataFrame
evaluation_df['Translated Dutch'] = croatian_to_dutch_translations
evaluation_df['Translated Croatian'] = dutch_to_croatian_translations
evaluation_df['Croatian to Dutch BLEU'] = croatian_to_dutch_bleu_scores
evaluation_df['Dutch to Croatian BLEU'] = dutch_to_croatian_bleu_scores
# Out:
#   0%|          | 0/279 [00:00<?, ?it/s]

# %%
evaluation_df["Croatian to Dutch BLEU"].mean()
# Out:
# 9.912537643364082

# %%
evaluation_df["Dutch to Croatian BLEU"].mean()
# Out:
# 5.108418677483671

# %%
evaluation_df.head(50)
# Out:
#     Unnamed: 0                                              Dutch  \
# 0            0  Op maandag kondigden wetenschappers van de Sta...
# 1            1  Hoofdonderzoekers zeggen dat dit kan leiden to...
# 2            2  De JAS 39C Gripen stortte rond 09.30 uur lokal...
# 3            3  De piloot werd geïdentificeerd als majoor Dilo...
# 4            4  De lokale media meldt dat er tijdens een actie...
# 5            5  De 28-jaar oude Vidal is drie seizoenen gelede...
# 6            6  Sinds hij verhuisde naar de Catalaanse hoofdst...
# 7            7  Het protest begon rond 11.00 lokale tijd (UTC+...
# 8            8  Iets na 11.00 uur begonnen betogers het verkee...
# 9            9  Om 11:20 vroeg de politie aan de demonstranten...
# 10          10  Vanaf 11.29 uur verplaatsten de demonstranten ...
# 11          11  Het onderlinge record van Nadal tegen de Canad...
# 12          12  Eerder leed hij een nederlaag tegen Raonic in ...
# 13          13  Nadal won 88% van de netpunten in de wedstrijd...
# 14          14   Na de wedstrijd zei De Gravelkoning, 'Ik ben ...
# 15          15  Het overkoepelde begrip de 'Panama Papers' ver...
# 16          16  Uit de documenten blijkt dat veertien banken r...
# 17          17  Volgens de Britse krant The Guardian beheerde ...
# 18          18  Er werd wereldwijd geprotesteerd, verschillend...
# 19          19  De in Hongkong geboren Ma studeerde aan de New...
# 20          20  Tijdens de verkiezingen liet Hsieh doorschemer...
# 21          21  Volgens Hsieh was de fotogenieke Ma wel stijlv...
# 22          22  Hoewel deze beschuldigingen werden geuit, won ...
# 23          23  De Speler van de Dag is Alex Ovechkin van de W...
# 24          24  In de wedstrijd waarin Washington met 5-3 van ...
# 25          25  Ovechkins eerste assist van de avond was op he...
# 26          26  Zijn tweede doelpunt van de avond was zijn 60s...
# 27          27  Batten stond in 2008 op plaats 190 op de lijst...
# 28          28  In 1950 haalde hij een diploma aan het College...
# 29          29  Bij een oproer staken mensen de Abu Ghraib-gev...
# 30          30  De gevangenis werd berucht toen misbruik van g...
# 31          31  Piquet Jr. crashte in de Grand Prix van Singap...
# 32          32  Terwijl de wagens vóór Alonso onder de safety ...
# 33          33  Piquet jr. werd in 2009 ontslagen na de Grand ...
# 34          34  Om precies 8.46 uur werd het doodstil in de st...
# 35          35  Er zijn twee lichtbundels geplaatst die 's nac...
# 36          36  Er wordt momenteel aan vijf nieuwe wolkenkrabb...
# 37          37  De PBS-show heeft meer dan twintig Emmy's gewo...
# 38          38  Elke aflevering van het programma richtte zich...
# 39          39  Elke show bevatte ook tips voor boeken die kin...
# 40          40  John Grant van WNED Buffalo (het station van R...
# 41          41  Sommige mensen, zoals John Grant, geloven dat ...
# 42          42  De storm bevindt zich ongeveer 645 mijl (1040 ...
# 43          43  Momenteel bereikt Fred windsnelheden van 105 m...
# 44          44  Fred is de sterkste tropische orkaan die sinds...
# 45          45  Op 24 september 1759 sloot Arthur Guinness een...
# 46          46  250 jaar later is Guinness een wereldwijd bedr...
# 47          47  Jonny Reid, bijrijder van het A1GP-team van Ni...
# 48          48  Het lukte dhr. Reid om met Black Beauty, de A1...
# 49          49  De Nieuw-Zeelandse politie kon nauwelijks met ...
#
#                                              Croatian  \
# 0   U ponedjeljak su znanstvenici s Medicinskog fa...
# 1   Voditelji istraživanja izjavili su da bi ovo o...
# 2   JAS 39C Gripen srušio se na pistu i eksplodira...
# 3   Pilot je identificiran kao zapovjednik eskadri...
# 4   Lokalni mediji izvješćuju da je došlo do prevr...
# 5   28-godišnji Vidal došao je iz Seville u Barçu ...
# 6   Vidal je za klub odigrao 49 utakmica otkako se...
# 7   Prosvjed je započeo oko 11:00 po lokalnom vrem...
# 8   Netom iza 11:00 h prosvjednici su blokirali pr...
# 9   Policija je u 11:20 zatražila od prosvjednika ...
# 10  Oko 11:29 h prosvjedna povorka krenula je dalj...
# 11  Nadalov rekord u izravnom sučeljavanju protiv ...
# 12  Nedavno je izgubio meč protiv Raonica na turni...
# 13  Nadal je osvojio 88 % bodova s mreže i osvojio...
# 14  "Nakon meča Kralj zemlje je izjavio: ""Jednost...
# 15  """Panamski dokumenti"" općeniti je pojam za p...
# 16  Sadržaj dokumenata ukazuje na to da su banke p...
# 17  Prema navodima u britanskim novinama The Guard...
# 18  Izbili su prosvjedi u cijelom svijetu, nekolik...
# 19  "Ma je rođen u Hong Kongu i studirao je na sve...
# 20  Hsieh je tijekom izbora natuknuo da bi Ma moga...
# 21  Hsieh je također tvrdio da fotogenični Ma ima ...
# 22  Unatoč optužbama, Ma je odnio uvjerljivu pobje...
# 23  Današnji Igrač dana je Alex Ovechkin iz Washin...
# 24  Postigao je 2 gola i 2 asistencije u pobjedi W...
# 25  Ovechkinova prva asistencija večeri bila je za...
# 26  njegov drugi gol večeri ujedno je bio i njegov...
# 27  Batten je zauzeo 190. mjesto na popisu 400 naj...
# 28  Diplomirao je na fakultetu umjetnosti i znanos...
# 29  Tijekom nereda je došlo do požara u iračkom za...
# 30  Zatvor je došao na loš glas nakon što su otkri...
# 31  Piquet Jr. doživio je sudar u sklopu Velike na...
# 32  Kad su automobili ispred Alonsa krenuli puniti...
# 33  Picquet Jr. smijenjen je nakon mađarskog Grand...
# 34  Točno u 8:46 nastupila je tišina, označavajući...
# 35   Dva snopa svjetlosti noću će osvjetljavati nebo.
# 36  Na lokaciji se gradi pet novih nebodera, s tra...
# 37  PBS-ova emisija osvojila je dvadesetak nagrada...
# 38  Svaka epizoda emisije bila je usredotočena na ...
# 39  U svakoj epizodi nudile su se preporuke za knj...
# 40  "John Grant, s televizijske postaje WNED Buffa...
# 41  Neki, među kojima i John Grant, smatraju da su...
# 42  Prognostičari tvrde da će se oluja, koja se tr...
# 43  Uragan Fred trenutno ima vjetrove brzine 105 m...
# 44  Fred je najsnažnija tropska oluja ikad zabilje...
# 45  24. rujna 1759. godine Arthur Guinness potpisa...
# 46  250 godina kasnije Guinness je postao globalna...
# 47  Jonny Reid, suvozač novozelandskog A1GP tima, ...
# 48  Gospodin Reid uspio je voziti automobil novoze...
# 49  Novozelandska policija nije uspjela provjeriti...
#
#                                      Translated Dutch  \
# 0   On Monday, scientists at Stanford Medical Scho...
# 1   Onderzoekers hebben aangetoond dat deze ontdek...
# 2   JAS 39C Gripen crashed in de pis en exploded r...
# 3   De pilot is identified as Commander Dilokrit P...
# 4   De local media reports that there was een vrac...
# 5   Vidal, 28 jaar oud, kwam uit Seville, to Bars,...
# 6   Vidal had 49 spells voor het club sinds hij ve...
# 7   De bewaking begon rond 11:00 local time in Whi...
# 8   Het was net 11: 00 p.m. dat protesters aan de ...
# 9   Om 11:20 p.m., de politie riep de protesters o...
# 10  Om 11:29 p.m. ging de protester verder door Wh...
# 11  De volgende record in direct contact met de Ca...
# 12  Hij verloor zijn match tegen Raonic in de Bris...
# 13  Hij haalde 88% van de grid en 76 van de eerste...
# 14  De koning van de land zei: "" Ik ben alleen ma...
# 15  "Panamaanse documenten" is een algemeen begrip...
# 16  De dossiers to date to show that banks had hel...
# 17  De British newspaper The Guardian noted that D...
# 18  Er zijn protests over de hele wereld, een aant...
# 19  "Ma was born in Hong Kong en studeerde in New ...
# 20  In de verkiezingen had Hsieh bedacht dat Ma in...
# 21  Hsieh also claimed that the photogenic Ma had ...
# 22  In spite of the accusations, Ma won overtuigin...
# 23  Tegenwoordig is Alex Ovechkin from Washington ...
# 24  Hij had 2 goals en 2 assists in een 5-3 win ov...
# 25  Ovechkin's eerste assist of the evening was fo...
# 26  Zijn tweede gol op de avond was also zijn 60st...
# 27  Batten was 190 in the 400 richest Americans in...
# 28  Hij had een diploma in kunst en wetenschap aan...
# 29         In de riots was het Abu Ghraib-gevangenis.
# 30  De gevangenis had een slechter stem toen de ge...
# 31  Piquet Jr. had a crash as part of the Singapor...
# 32  Als de auto's in front van Alonsa begonnen te ...
# 33  Picquet Jr. is mocked after the 2009 Hungarian...
# 34  Op exact 8:46 was the silence, marking het exa...
# 35         Twee laden lights at night beamen the sky.
# 36  Er zijn vijf nieuwe skyscrapers in de buurt, m...
# 37  PBS won 20 Emmy Awards, en de enige shows die ...
# 38  Elke episode van de show was te maken met het ...
# 39  In each episode, there were recommendations fo...
# 40  John Grant, van WNED Buffalo, said, "The Readi...
# 41  Sommigen, including John Grant, believe that d...
# 42  Forecasters say that the storm, which is curre...
# 43  Hurricane Fred is currently 105 miles per hour...
# 44  Fred is the strongest tropical cyclone ever re...
# 45  Op 24 September 1759, had Arthur Guinness een ...
# 46  250 jaar later is Guinness een wereldwijd bedr...
# 47  Jonny Reid, leader van de New Zealand A1GP tea...
# 48  Mr. Reid drove a New Zealand A1GP team, the Bl...
# 49  De politie in New Zealand was niet in staat om...
#
#                                   Translated Croatian  Croatian to Dutch BLEU  \
# 0   Monday, scientists from the Stanford Universit...                2.137018
# 1   Znanstvenici say this can lead to early detect...               11.305237
# 2   JAS 39C Gripen jeoparm jeoparm jeoparm jeoparm...                5.913213
# 3   A pilot was identified as Major Dilokrit Patta...               19.070828
# 4   I've heard from the local media that there was...                4.780204
# 5   28-ogodišnjak Vidal je prešao s Sevilla na Bar...                3.234245
# 6                 I've played 49 matches for the club               18.751145
# 7   Demonstracija je započela oko 11: 00 local tim...                6.667754
# 8   Otprilike 11: 00, protesters began to block tr...                2.519759
# 9   U 11:20, the police demanded that the demonstr...                9.748573
# 10  Od 11: 29, the demonstracija jela u Whitehall,...                9.571600
# 11       Nadal's record against the Canadiens is 7-2.                8.889176
# 12     I used to lose to Raonic at the Brisbane Open.               52.108337
# 13  Nadal won 88% of the nets in the match, achiev...               13.779594
# 14  Nakoneg, "" The Gravelkoning "" said, "I'm jus...               13.423393
# 15  Prenotice, "Panama Papers" refers to about 10 ...                7.669315
# 16  Dokumente show that 14 banks, rich clients, he...                1.622966
# 17  According to The Guardian, Deutsche Bank contr...                5.154338
# 18  Around the world, there were protests, various...                5.618923
# 19  Ma, born in Hong Kong, studied at New York Uni...                4.368410
# 20  During the elections, Hsieh predicted that Ma ...                8.532099
# 21  Hsieh thought the "" Ma "" was stylish, but it...                2.352622
# 22  No, although these accusations were levelled, ...                2.453340
# 23  "" Player of the Day "" is Alex Ovechkin from ...               18.505100
# 24  U meczu gdje je Washington pobijedio 5-3 od At...               14.514039
# 25  Ovechkin's first assist of the night was a win...                5.993031
# 26  His second goal of the night was his 60th of t...               17.765447
# 27  U 2008., Batten je bio 190th on the list of 40...                5.062007
# 28  1950, got diploma from the College of Arts & S...                5.472538
# 29  U vrijeme revolucije, people burned Abu Ghraib...                7.030418
# 30  Zatacija je bila osuđena kada je bilo osuđena ...                6.312749
# 31  Piquet Jr. crashed in the 2008 Singaporean Gra...                9.616856
# 32  I mean, as the cars in front of Alonso started...                7.575731
# 33  Piquet J. was sacked in 2009 after the Hungari...                7.209140
# 34  Around 8.46, the city became mirom. This was a...                4.122623
# 35   I've got two sets of lights that go up at night.                3.817681
# 36  I'm currently building five new skyscrapers, w...               22.813997
# 37  PBS show has won over 20 Emmy Awards, and they...                8.237074
# 38  I've every episode focused on a theme from a b...                4.943884
# 39  Each show included tips for books that kids co...                5.401157
# 40  John Grant from WNED Buffalo, said, "Reading R...                3.569214
# 41  Some people, like John Grant, believe that the...                6.253457
# 42  Ovaj će se nalaziti oko 645 milja west of the ...                3.272544
# 43  Currently, Fred's going 105 miles per hour, an...                2.257253
# 44  Fred is the strongest tropical cyclone ever me...                2.939821
# 45  On 24 September 1759, Arthur Guinness struck 9...               20.472658
# 46  250 years later, Guinness World Company is a g...               34.882193
# 47  Jonny Reid, a New Zealander A1GP teamer, is to...               10.922503
# 48  Dr. Reid, sa Black Beauty, New Zealand's A1GP ...                8.486535
# 49  I mean, the New Zealand police could barely de...                3.343260
#
#     Dutch to Croatian BLEU
# 0                 0.961745
# 1                 1.175609
# 2                 3.321510
# 3                17.747405
# 4                 2.033127
# 5                 6.608974
# 6                 2.094347
# 7                24.297792
# 8                10.704546
# 9                 4.595432
# 10                7.346000
# 11                7.603986
# 12               13.950797
# 13                5.091213
# 14                3.930770
# 15                3.754163
# 16                1.794616
# 17               14.464261
# 18                2.273154
# 19                1.470117
# 20                2.826521
# 21                2.444829
# 22                3.644667
# 23                5.816635
# 24                4.885327
# 25                3.699964
# 26                2.765801
# 27                4.491576
# 28                1.870972
# 29                7.495553
# 30                1.717906
# 31                5.157017
# 32                1.650405
# 33                4.368584
# 34                2.159701
# 35                3.386499
# 36                2.407486
# 37                6.649323
# 38                1.816085
# 39                2.292084
# 40                3.151519
# 41                5.442134
# 42                3.778299
# 43                1.959773
# 44                1.294453
# 45                7.608486
# 46                1.639596
# 47                8.369018
# 48                6.120673
# 49                7.144376

# %%
from nltk.translate.meteor_score import single_meteor_score
from nltk import word_tokenize
from tqdm import tqdm
import nltk

# Download NLTK's tokenizer models
nltk.download('punkt')
nltk.download('wordnet')

# Initialize the lists to store METEOR scores
dutch_to_croatian_meteor_scores = []
croatian_to_dutch_meteor_scores = []

# Loop through each row in the DataFrame
for _, row in tqdm(evaluation_df.iterrows(), total=evaluation_df.shape[0]):
    # Tokenize the Dutch and Croatian sentences
    reference_dutch = word_tokenize(row['Dutch'])
    hypothesis_croatian_to_dutch = word_tokenize(row['Translated Dutch'])
    reference_croatian = word_tokenize(row['Croatian'])
    hypothesis_dutch_to_croatian = word_tokenize(row['Translated Croatian'])

    # Calculate the METEOR score for Dutch to Croatian translation
    dutch_to_croatian_score = single_meteor_score(reference_croatian, hypothesis_dutch_to_croatian)
    dutch_to_croatian_meteor_scores.append(dutch_to_croatian_score)

    # Calculate the METEOR score for Croatian to Dutch translation
    croatian_to_dutch_score = single_meteor_score(reference_dutch, hypothesis_croatian_to_dutch)
    croatian_to_dutch_meteor_scores.append(croatian_to_dutch_score)

# Add the METEOR scores to DataFrame
evaluation_df['Croatian to Dutch METEOR'] = croatian_to_dutch_meteor_scores
evaluation_df['Dutch to Croatian METEOR'] = dutch_to_croatian_meteor_scores

# Display the updated DataFrame
print(evaluation_df.head())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 100%|██████████| 2226/2226 [00:10<00:00, 203.39it/s]
#    Unnamed: 0                                              Dutch  \
# 0           0  Op maandag kondigden wetenschappers van de Sta...
# 1           1  Hoofdonderzoekers zeggen dat dit kan leiden to...
# 2           2  De JAS 39C Gripen stortte rond 09.30 uur lokal...
# 3           3  De piloot werd geïdentificeerd als majoor Dilo...
# 4           4  De lokale media meldt dat er tijdens een actie...
#
#                                             Croatian  \
# 0  U ponedjeljak su znanstvenici s Medicinskog fa...
# 1  Voditelji istraživanja izjavili su da bi ovo o...
# 2  JAS 39C Gripen srušio se na pistu i eksplodira...
# 3  Pilot je identificiran kao zapovjednik eskadri...
# 4  Lokalni mediji izvješćuju da je došlo do prevr...
#
#                                     Translated Dutch  \
# 0  On Monday, scientists at Stanford Medical Scho...
# 1  Onderzoekers hebben aangetoond dat deze ontdek...
# 2  JAS 39C Gripen crashed in de pis en exploded r...
# 3  De pilot is identified as Commander Dilokrit P...
# 4  De local media reports that there was een vrac...
#
#                                  Translated Croatian  Croatian to Dutch BLEU  \
# 0  Monday, scientists from the Stanford Universit...                2.137018
# 1  Znanstvenici say this can lead to early detect...               11.305237
# 2  JAS 39C Gripen jeoparm jeoparm jeoparm jeoparm...                5.913213
# 3  A pilot was identified as Major Dilokrit Patta...               19.070828
# 4  I've heard from the local media that there was...                4.780204
#
#    Dutch to Croatian BLEU  Croatian to Dutch METEOR  Dutch to Croatian METEOR
# 0                0.961745                  0.133229                  0.022523
# 1                1.175609                  0.374371                  0.045872
# 2                3.321510                  0.194711                  0.099474
# 3               17.747405                  0.416667                  0.416667
# 4                2.033127                  0.245051                  0.026455

# %%
print(evaluation_df["Croatian to Dutch METEOR"].mean())
# Out:
# 0.2795983714525936

# %%
print(evaluation_df["Dutch to Croatian METEOR"].mean())
# Out:
# 0.12428641344287146

# %%
# !pip install evaluate
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)

# %%
# !pip install unbabel-comet
# Out:
# Requirement already satisfied: unbabel-comet in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: entmax<2.0,>=1.1 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (1.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (0.20.3)
# Requirement already satisfied: jsonargparse==3.13.1 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (3.13.1)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (1.25.2)
# Requirement already satisfied: pandas>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (1.5.3)
# Requirement already satisfied: protobuf<5.0.0,>=4.24.4 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (4.25.3)
# Requirement already satisfied: pytorch-lightning<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (2.2.0.post0)
# Requirement already satisfied: sacrebleu<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (2.4.0)
# Requirement already satisfied: scipy<2.0.0,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (1.11.4)
# Requirement already satisfied: sentencepiece<0.2.0,>=0.1.96 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (0.1.99)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (2.1.0+cu121)
# Requirement already satisfied: torchmetrics<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (0.10.3)
# Requirement already satisfied: transformers<5.0,>=4.17 in /usr/local/lib/python3.10/dist-packages (from unbabel-comet) (4.38.2)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from jsonargparse==3.13.1->unbabel-comet) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.1->unbabel-comet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.1->unbabel-comet) (2023.4)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (0.10.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu<3.0.0,>=2.0.0->unbabel-comet) (4.9.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->unbabel-comet) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0,>=4.17->unbabel-comet) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0,>=4.17->unbabel-comet) (0.4.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4.1->unbabel-comet) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->unbabel-comet) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->unbabel-comet) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec>=2023.5.0->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.0.3)

# %%
from evaluate import load
comet_metric = load('comet')
# Out:
# Downloading builder script:   0%|          | 0.00/6.97k [00:00<?, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# hparams.yaml:   0%|          | 0.00/567 [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/9.69k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.53k [00:00<?, ?B/s]
# model.ckpt:   0%|          | 0.00/2.32G [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.8.3.post1 to v2.2.0.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/huggingface/hub/models--Unbabel--wmt22-comet-da/snapshots/371e9839ca4e213dde891b066cf3080f75ec7e72/checkpoints/model.ckpt`
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/saving.py:188: Found keys that are not in the model state dict but in the checkpoint: ['encoder.model.embeddings.position_ids']

# %%
import numpy as np
from tqdm import tqdm

# Function to compute COMET scores in batches
def compute_comet_in_batches(data, batch_size=100):
    scores = []
    for i in tqdm(range(0, len(data['sources']), batch_size)):
        batch = {
            "sources": data['sources'][i:i+batch_size],
            "predictions": data['predictions'][i:i+batch_size],
            "references": data['references'][i:i+batch_size]
        }
        batch_results = comet_metric.compute(predictions=batch["predictions"], references=batch["references"], sources=batch["sources"])
        scores.extend(batch_results["scores"])
    return scores

# Croatian to Dutch COMET scores
data_cro_to_dut = {
    "sources": evaluation_df['Croatian'].tolist(),
    "predictions": evaluation_df['Translated Dutch'].tolist(),
    "references": evaluation_df['Dutch'].tolist()
}

cro_to_dut_scores = compute_comet_in_batches(data_cro_to_dut)
evaluation_df['Croatian to Dutch COMET'] = [round(score, 5) for score in cro_to_dut_scores]

# Dutch to Croatian COMET scores
data_dut_to_cro = {
    "sources": evaluation_df['Dutch'].tolist(),
    "predictions": evaluation_df['Translated Croatian'].tolist(),
    "references": evaluation_df['Croatian'].tolist()
}

dut_to_cro_scores = compute_comet_in_batches(data_dut_to_cro)
evaluation_df['Dutch to Croatian COMET'] = [round(score, 5) for score in dut_to_cro_scores]

# Display the updated DataFrame
print(evaluation_df.head())
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   4%|▍         | 1/23 [00:07<02:38,  7.22s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   9%|▊         | 2/23 [00:15<02:44,  7.82s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  13%|█▎        | 3/23 [00:21<02:24,  7.22s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  17%|█▋        | 4/23 [00:29<02:21,  7.45s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  22%|██▏       | 5/23 [00:36<02:10,  7.28s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  26%|██▌       | 6/23 [00:42<01:57,  6.91s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  30%|███       | 7/23 [00:47<01:39,  6.23s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  35%|███▍      | 8/23 [00:52<01:26,  5.79s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  39%|███▉      | 9/23 [00:58<01:19,  5.69s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  43%|████▎     | 10/23 [01:02<01:10,  5.39s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  48%|████▊     | 11/23 [01:08<01:05,  5.44s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  52%|█████▏    | 12/23 [01:12<00:55,  5.09s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  57%|█████▋    | 13/23 [01:17<00:48,  4.88s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  61%|██████    | 14/23 [01:22<00:44,  4.92s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  65%|██████▌   | 15/23 [01:26<00:38,  4.80s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  70%|██████▉   | 16/23 [01:31<00:33,  4.76s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  74%|███████▍  | 17/23 [01:36<00:29,  4.90s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  78%|███████▊  | 18/23 [01:40<00:23,  4.74s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  83%|████████▎ | 19/23 [01:45<00:18,  4.68s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  87%|████████▋ | 20/23 [01:50<00:14,  4.77s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  91%|█████████▏| 21/23 [01:54<00:09,  4.58s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  96%|█████████▌| 22/23 [01:59<00:04,  4.57s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 100%|██████████| 23/23 [02:05<00:00,  5.47s/it]
#   0%|          | 0/23 [00:00<?, ?it/s]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   4%|▍         | 1/23 [00:04<01:39,  4.54s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   9%|▊         | 2/23 [00:09<01:38,  4.69s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  13%|█▎        | 3/23 [00:14<01:34,  4.73s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  17%|█▋        | 4/23 [00:18<01:27,  4.59s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  22%|██▏       | 5/23 [00:23<01:26,  4.81s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  26%|██▌       | 6/23 [00:28<01:20,  4.72s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  30%|███       | 7/23 [00:32<01:13,  4.59s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  35%|███▍      | 8/23 [00:37<01:10,  4.71s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  39%|███▉      | 9/23 [00:41<01:04,  4.62s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  43%|████▎     | 10/23 [00:46<00:59,  4.55s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  48%|████▊     | 11/23 [00:51<00:56,  4.72s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  52%|█████▏    | 12/23 [00:55<00:50,  4.63s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  57%|█████▋    | 13/23 [01:00<00:45,  4.55s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  61%|██████    | 14/23 [01:05<00:42,  4.68s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  65%|██████▌   | 15/23 [01:10<00:38,  4.75s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  70%|██████▉   | 16/23 [01:15<00:33,  4.79s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  74%|███████▍  | 17/23 [01:19<00:28,  4.79s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  78%|███████▊  | 18/23 [01:24<00:23,  4.67s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  83%|████████▎ | 19/23 [01:28<00:18,  4.67s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  87%|████████▋ | 20/23 [01:33<00:14,  4.72s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  91%|█████████▏| 21/23 [01:37<00:09,  4.52s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  96%|█████████▌| 22/23 [01:42<00:04,  4.44s/it]INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 100%|██████████| 23/23 [01:46<00:00,  4.61s/it]
#    Unnamed: 0                                              Dutch  \
# 0           0  Op maandag kondigden wetenschappers van de Sta...
# 1           1  Hoofdonderzoekers zeggen dat dit kan leiden to...
# 2           2  De JAS 39C Gripen stortte rond 09.30 uur lokal...
# 3           3  De piloot werd geïdentificeerd als majoor Dilo...
# 4           4  De lokale media meldt dat er tijdens een actie...
#
#                                             Croatian  \
# 0  U ponedjeljak su znanstvenici s Medicinskog fa...
# 1  Voditelji istraživanja izjavili su da bi ovo o...
# 2  JAS 39C Gripen srušio se na pistu i eksplodira...
# 3  Pilot je identificiran kao zapovjednik eskadri...
# 4  Lokalni mediji izvješćuju da je došlo do prevr...
#
#                                     Translated Dutch  \
# 0  On Monday, scientists at Stanford Medical Scho...
# 1  Onderzoekers hebben aangetoond dat deze ontdek...
# 2  JAS 39C Gripen crashed in de pis en exploded r...
# 3  De pilot is identified as Commander Dilokrit P...
# 4  De local media reports that there was een vrac...
#
#                                  Translated Croatian  Croatian to Dutch BLEU  \
# 0  Monday, scientists from the Stanford Universit...                2.137018
# 1  Znanstvenici say this can lead to early detect...               11.305237
# 2  JAS 39C Gripen jeoparm jeoparm jeoparm jeoparm...                5.913213
# 3  A pilot was identified as Major Dilokrit Patta...               19.070828
# 4  I've heard from the local media that there was...                4.780204
#
#    Dutch to Croatian BLEU  Croatian to Dutch METEOR  Dutch to Croatian METEOR  \
# 0                0.961745                  0.133229                  0.022523
# 1                1.175609                  0.374371                  0.045872
# 2                3.321510                  0.194711                  0.099474
# 3               17.747405                  0.416667                  0.416667
# 4                2.033127                  0.245051                  0.026455
#
#    Croatian to Dutch COMET  Dutch to Croatian COMET
# 0                  0.64900                  0.44438
# 1                  0.64009                  0.52624
# 2                  0.53131                  0.23477
# 3                  0.76856                  0.69039
# 4                  0.49873                  0.30317

# %%
evaluation_df
# Out:
#       Unnamed: 0                                              Dutch  \
# 0              0  Op maandag kondigden wetenschappers van de Sta...
# 1              1  Hoofdonderzoekers zeggen dat dit kan leiden to...
# 2              2  De JAS 39C Gripen stortte rond 09.30 uur lokal...
# 3              3  De piloot werd geïdentificeerd als majoor Dilo...
# 4              4  De lokale media meldt dat er tijdens een actie...
# ...          ...                                                ...
# 2221         212                               Mijn naam is Andrea.
# 2222         213                            Jupiter is een planeet.
# 2223         214                              Venus is een planeet.
# 2224         215                                God is een olifant.
# 2225         216                              Muziek is mijn leven.
#
#                                                Croatian  \
# 0     U ponedjeljak su znanstvenici s Medicinskog fa...
# 1     Voditelji istraživanja izjavili su da bi ovo o...
# 2     JAS 39C Gripen srušio se na pistu i eksplodira...
# 3     Pilot je identificiran kao zapovjednik eskadri...
# 4     Lokalni mediji izvješćuju da je došlo do prevr...
# ...                                                 ...
# 2221                                Moje ime je Andrea.
# 2222                                 Jupiter je planet.
# 2223                                  Venera je planet.
# 2224                                       Bog je slon.
# 2225                               Glazba je moj život.
#
#                                        Translated Dutch  \
# 0     On Monday, scientists at Stanford Medical Scho...
# 1     Onderzoekers hebben aangetoond dat deze ontdek...
# 2     JAS 39C Gripen crashed in de pis en exploded r...
# 3     De pilot is identified as Commander Dilokrit P...
# 4     De local media reports that there was een vrac...
# ...                                                 ...
# 2221                               Mijn naam is Andrea.
# 2222                               Jupiter is a planet.
# 2223                                 Venus is a planet.
# 2224                                God is an elephant.
# 2225                                  Music is my life.
#
#                                     Translated Croatian  \
# 0     Monday, scientists from the Stanford Universit...
# 1     Znanstvenici say this can lead to early detect...
# 2     JAS 39C Gripen jeoparm jeoparm jeoparm jeoparm...
# 3     A pilot was identified as Major Dilokrit Patta...
# 4     I've heard from the local media that there was...
# ...                                                 ...
# 2221                                Moje ime je Andrea.
# 2222                                 Jupiter je planet.
# 2223                                   Venus je planet.
# 2224                                God is an elephant.
# 2225                                 Muzica je my life.
#
#       Croatian to Dutch BLEU  Dutch to Croatian BLEU  \
# 0                   2.137018                0.961745
# 1                  11.305237                1.175609
# 2                   5.913213                3.321510
# 3                  19.070828               17.747405
# 4                   4.780204                2.033127
# ...                      ...                     ...
# 2221              100.000000              100.000000
# 2222               23.643540              100.000000
# 2223               23.643540               59.460356
# 2224               23.643540               10.682175
# 2225               12.703319               12.703319
#
#       Croatian to Dutch METEOR  Dutch to Croatian METEOR  \
# 0                     0.133229                  0.022523
# 1                     0.374371                  0.045872
# 2                     0.194711                  0.099474
# 3                     0.416667                  0.416667
# 4                     0.245051                  0.026455
# ...                        ...                       ...
# 2221                  0.996000                  0.996000
# 2222                  0.511111                  0.992188
# 2223                  0.511111                  0.736111
# 2224                  0.511111                  0.121951
# 2225                  0.200000                  0.200000
#
#       Croatian to Dutch COMET  Dutch to Croatian COMET
# 0                     0.64900                  0.44438
# 1                     0.64009                  0.52624
# 2                     0.53131                  0.23477
# 3                     0.76856                  0.69039
# 4                     0.49873                  0.30317
# ...                       ...                      ...
# 2221                  0.99040                  0.99322
# 2222                  0.90708                  0.98727
# 2223                  0.88377                  0.93232
# 2224                  0.74346                  0.55488
# 2225                  0.90439                  0.94763
#
# [2226 rows x 11 columns]

# %%
print(evaluation_df["Croatian to Dutch COMET"].mean())
# Out:
# 0.6467908221024259

# %%
print(evaluation_df["Dutch to Croatian COMET"].mean())
# Out:
# 0.5592741464510332

# %%
evaluation_df.to_csv('/content/drive/MyDrive/mbart50_large_evaluation_1.csv')
